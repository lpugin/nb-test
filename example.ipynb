# %%
import verovio

# %%
tk = verovio.toolkit()
tk.setOptions("{'scale': 30}")
# Out:
# True

# %%
tk.loadFile('test-02.mei')
# Out:
# True

# %%
tk.renderToSVGFile('test.svg', 1)
# Out:
# True

# %%
display('test.svg')
# Out:
# 'test.svg'

# %%
from IPython.display import SVG

# %%
SVG('test.svg')

# %%
svg = tk.renderToSVG(1)

# %%
SVG(svg)
